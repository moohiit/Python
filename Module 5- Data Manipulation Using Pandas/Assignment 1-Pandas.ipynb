# %% [markdown]
# # Tasks to be performed:

# %% [markdown]
# 1. Start off by importing the customer_churn.csv file in the jupyter notebook and store that in churn data
# frame.

# %%
import pandas as pd 
from pathlib import Path
import os

churn_dataset=pd.read_csv(Path("customer_churn.csv"))
churn_dataset.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# 2. From the churn data frame, select only 3rd, 7th, 9th, and 20th columns and all the rows and store that in new
# data frame named newCols.

# %%
newCols=churn_dataset[["SeniorCitizen","PhoneService","InternetService","Churn"]]
newCols
# Out:
#       SeniorCitizen PhoneService InternetService Churn
# 0                 0           No             DSL    No
# 1                 0          Yes             DSL    No
# 2                 0          Yes             DSL   Yes
# 3                 0           No             DSL    No
# 4                 0          Yes     Fiber optic   Yes
# ...             ...          ...             ...   ...
# 7038              0          Yes             DSL    No
# 7039              0          Yes     Fiber optic    No
# 7040              0           No             DSL    No
# 7041              1          Yes     Fiber optic   Yes
# 7042              0          Yes     Fiber optic    No
#
# [7043 rows x 4 columns]

# %% [markdown]
# 3. From the original data frame, select only the rows from 200th index till 1000th index(inclusive) column.

# %%
select=churn_dataset.iloc[200:1001,:]
select
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 200   9323-HGFWY  Female              0     Yes         No      27
# 201   8544-GOQSH  Female              0      No         No      14
# 202   3363-DTIVD    Male              0     Yes        Yes      71
# 203   7018-WBJNK    Male              0      No        Yes      13
# 204   9142-KZXOP    Male              0      No         No      44
# ...          ...     ...            ...     ...        ...     ...
# 996   6641-XRPSU  Female              0      No         No      34
# 997   1374-DMZUI  Female              1      No         No       4
# 998   2545-LXYVJ    Male              0     Yes         No      72
# 999   3234-VKACU    Male              0      No         No       2
# 1000  8357-EQXFO  Female              0      No         No       7
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 200           Yes            No     Fiber optic                  Yes  ...
# ...

# %% [markdown]
# 4. Now select the rows from 20th index till 200th index(exclusive),and columns from 2nd index till 15th index
# value.

# %%
select=churn_dataset.iloc[20:201,2:16]
select
# Out:
#      SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 20               1      No         No       1           No  No phone service
# 21               0     Yes         No      12          Yes                No
# 22               0      No         No       1          Yes                No
# 23               0     Yes         No      58          Yes               Yes
# 24               0     Yes        Yes      49          Yes                No
# ..             ...     ...        ...     ...          ...               ...
# 196              0     Yes        Yes      24          Yes               Yes
# 197              0      No         No      59          Yes               Yes
# 198              0     Yes        Yes      72          Yes               Yes
# 199              0      No        Yes       1          Yes                No
# 200              0     Yes         No      27          Yes                No
#
# ...

# %% [markdown]
# 5. Display the top 100 records from the original data frame.

# %%
select=churn_dataset.iloc[:100]
select
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
# 99  4598-XLKNJ  Female              1     Yes         No      25          Yes
#
# ...

# %% [markdown]
# 6. Display the last 10 records from the data frame.

# %%
last=churn_dataset.tail(10)
last
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %% [markdown]
# 7. Display the last record from the data frame.

# %%
lastrecord=churn_dataset.iloc[-1:]
lastrecord
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 7042          Yes            No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 7042              Yes         Yes         Yes             Yes  Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7042    No
#
# [1 rows x 21 columns]

# %% [markdown]
# 8. Now from the churn data frame, try to sort the data by the tenure column according to the descending
# order.

# %%
sort=churn_dataset.sort_values(by=["tenure"],ascending=False).reset_index(drop=True)
sort
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     4737-AQCPU    Male              0     Yes        Yes      72
# 1     9680-NIAUV  Female              0     Yes        Yes      72
# 2     5914-XRFQB    Male              0     Yes         No      72
# 3     5168-MQQCA  Female              0     Yes         No      72
# 4     0464-WJTKO  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 7038  4367-NUYAO    Male              0     Yes        Yes       0
# 7039  3213-VVOLG    Male              0     Yes        Yes       0
# 7040  5709-LVOEQ  Female              0     Yes        Yes       0
# 7041  2775-SEFEE    Male              0      No        Yes       0
# 7042  1371-DWPAZ  Female              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0             Yes               Yes             DSL                  Yes  ...
# ...

# %% [markdown]
# 9. Fetch all the records that are satisfying the following condition:
# * a. Tenure>50 and the gender as ‘Female’.
# * b. Gender as ‘Male’ and SeniorCitizen as 0.
# * c. TechSupport as ‘Yes’ and Churn as ‘No’.
# * d. Contract type as ‘Month-to-month’ and Churn as ‘Yes’.

# %%
#A.Tenure>50 and the gender as ‘Female’.
filter=(churn_dataset['tenure']>50) & (churn_dataset['gender']=="Female")
churn_dataset[filter].reset_index(drop=True)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     3655-SNQYZ  Female              0     Yes        Yes      69
# 1     8191-XWSZG  Female              0      No         No      52
# 2     3638-WEABW  Female              0     Yes         No      58
# 3     3841-NFECX  Female              1     Yes         No      71
# 4     6234-RAAPL  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1017  1035-IPQPU  Female              1     Yes         No      63
# 1018  9281-CEDRU  Female              0     Yes         No      68
# 1019  0639-TSIQW  Female              0      No         No      67
# 1020  2569-WGERO  Female              0      No         No      72
# 1021  2234-XADUH  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 0             Yes           Yes     Fiber optic                  Yes  ...
# ...

# %%
#b. Gender as ‘Male’ and SeniorCitizen as 0.
filter1=(churn_dataset['gender']=="Male") & (churn_dataset["SeniorCitizen"]==0)
churn_dataset[filter1].reset_index(drop=True)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 0     5575-GNVDE   Male              0      No         No      34
# 1     3668-QPYBK   Male              0      No         No       2
# 2     7795-CFOCW   Male              0      No         No      45
# 3     1452-KIOVK   Male              0      No        Yes      22
# 4     6388-TABGU   Male              0      No        Yes      62
# ...          ...    ...            ...     ...        ...     ...
# 2976  0550-DCXLH   Male              0      No         No      13
# 2977  9767-FFLEM   Male              0      No         No      38
# 2978  8456-QDAVC   Male              0      No         No      19
# 2979  6840-RESVB   Male              0     Yes        Yes      24
# 2980  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             Yes                No             DSL            Yes  ...
# ...

# %%
#c. TechSupport as ‘Yes’ and Churn as ‘No’. 
filter2=(churn_dataset['TechSupport']=="Yes")&(churn_dataset['Churn']=="No")
churn_dataset[filter2]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3     7795-CFOCW    Male              0      No         No      45
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 23    3638-WEABW  Female              0     Yes         No      58
# 24    6322-HRPFA    Male              0     Yes        Yes      49
# ...          ...     ...            ...     ...        ...     ...
# 7027  0550-DCXLH    Male              0      No         No      13
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 3              No  No phone service             DSL            Yes  ...
# ...

# %%
#d. Contract type as ‘Month-to-month’ and Churn as ‘Yes’.
filter3=(churn_dataset['Contract']=='Month-to-month')&(churn_dataset['Churn']=='Yes')
churn_dataset[filter3]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %% [markdown]
# 10.  Use a for loop to calculate the number of customers that are getting the tech support and are male senior citizen.

# %%
filter4=(churn_dataset['TechSupport']=='Yes') & (churn_dataset['gender']=='Male') & (churn_dataset['SeniorCitizen']==1)

# %%
df=churn_dataset[filter4]
df
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 72    1891-QRQSA   Male              1     Yes        Yes      64
# 91    2424-WVHPL   Male              1      No         No       1
# 273   4716-HHKQH   Male              1     Yes         No      20
# 382   8204-YJCLA   Male              1     Yes        Yes      72
# ...          ...    ...            ...     ...        ...     ...
# 6601  4909-JOUPP   Male              1     Yes         No      72
# 6605  7632-MNYOY   Male              1      No         No      66
# 6763  7471-MQPOS   Male              1     Yes        Yes      71
# 6956  2451-YMUXS   Male              1      No         No      67
# 7007  2274-XUATA   Male              1     Yes         No      72
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 57            Yes               Yes     Fiber optic             No  ...
# ...

# %%
sum=0
for i in range(len(churn_dataset[filter4])):
    sum+=1
print("Total No of customers:",sum)
# Out:
# Total No of customers: 119
